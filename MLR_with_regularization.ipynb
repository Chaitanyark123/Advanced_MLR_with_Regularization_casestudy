# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 
import seaborn as sns

# %%
house_price = pd.read_csv("D:\\downloads\\train.csv")

# %%
house_price.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_price.shape
# Out:
# (1460, 81)

# %%
house_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house_price.isna().sum(axis=0).index
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
house_price=house_price.drop(house_price[house_price.isnull().sum(axis=1)>5].index,axis=0)

# %%
house_price[(house_price.isnull().sum(axis=0)>1314).indexx]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
cols=[]
for i in house_price.columns:
    if house_price[i].isnull().sum()<1314:
        cols.append(i)
len(cols)
# Out:
# 78

# %%
house_price.FireplaceQu
# Out:
# 0       NaN
# 1        TA
# 2        TA
# 3        Gd
# 4        TA
#        ...
# 1455     TA
# 1456     TA
# 1457     Gd
# 1458    NaN
# 1459    NaN
# Name: FireplaceQu, Length: 1460, dtype: object

# %%
house_price['PoolArea'].value_counts() #poolarea and pool quality
# Out:
# 0      1453
# 512       1
# 648       1
# 576       1
# 555       1
# 480       1
# 519       1
# 738       1
# Name: PoolArea, dtype: int64

# %%
house_price[['PoolArea','OverallCond']][house_price['PoolArea']>0]
# Out:
#       PoolArea  OverallCond
# 197        512            4
# 810        648            6
# 1170       576            6
# 1182       555            5
# 1298       480            5
# 1386       519            5
# 1423       738            7

# %%
house_price[house_price['OverallCond']>8]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 185    186          75       RM         90.0    22950   Pave   NaN      IR2
# 191    192          60       RL          NaN     7472   Pave   NaN      IR1
# 218    219          50       RL          NaN    15660   Pave   NaN      IR1
# 241    242          30       RM         40.0     3880   Pave   NaN      Reg
# 304    305          75       RM         87.0    18386   Pave   NaN      Reg
# 461    462          70       RL         60.0     7200   Pave   NaN      Reg
# 508    509          70       RM         60.0     9600   Pave   NaN      Reg
# 519    520          70       RL         53.0    10918   Pave   NaN      Reg
# 583    584          75       RM         75.0    13500   Pave   NaN      Reg
# 703    704         190       RM         76.0     7630   Pave   NaN      Reg
# 726    727          20       RL          NaN    21695   Pave   NaN      IR1
# ...

# %%
house_price[['OverallCond','OverallQual']].corr()
# Out:
#              OverallCond  OverallQual
# OverallCond     1.000000    -0.091932
# OverallQual    -0.091932     1.000000

# %%
new_df['RoofMatl']
# Out:
# 185     WdShngl
# 191     CompShg
# 218     CompShg
# 241     CompShg
# 304     CompShg
# 461     CompShg
# 508     CompShg
# 519     CompShg
# 583     CompShg
# 703     CompShg
# 726     CompShg
# 745     CompShg
# 980     CompShg
# 991     CompShg
# 1123    CompShg
# 1149    CompShg
# 1213    CompShg
# 1268    CompShg
# 1327    CompShg
# 1352    CompShg
# 1435    CompShg
# 1457    CompShg
# Name: RoofMatl, dtype: object
